# %%
import numpy as np
from pathlib import Path

X = np.load(r"data\sequences\X_train.npy")
print(f"Shape: {X.shape}")
print(f"Precip col mean: {X[:,:,0].mean():.4f}")
print(f"Precip col max:  {X[:,:,0].max():.4f}")
# Out:
# Shape: (6545, 30, 18)
# Precip col mean: 0.0110
# Precip col max:  1.0000
