# %%
import pandas as pd
from pathlib import Path

ROOT = Path("C:/Users/marck/Downloads/nahr_ibrahim_watershed")

hybrid_scaler = pd.read_csv(
    ROOT / "data/splits/scaler_params_h1_lb60_hybrid.csv", index_col=0
)

print("Hybrid scaler — all rows:")
print(hybrid_scaler)
print(f"\nIndex values: {list(hybrid_scaler.index)}")
print(f"\nColumns: {list(hybrid_scaler.columns)}")
# Out:
# Hybrid scaler — all rows:
#                          min         max
# precip_mm_day       0.000000  229.908981
# precip_3day         0.000000  267.208252
# precip_7day         0.000000  317.160553
# precip_14day        0.000000  397.537506
# precip_30day        0.000000  575.876831
# precip_60day        0.000000  915.284790
# precip_90day        0.000000  986.161255
# precip_lag1         0.000000  229.908981
# precip_lag2         0.000000  229.908981
# precip_lag3         0.000000  229.908981
# precip_lag5         0.000000  229.908981
# api_15d             0.000000  302.540466
# api_30d             0.000000  615.511047
# api_60d             0.000000  864.979919
# temp_mean_c        -8.242088   26.660328
# temp_max_c         -4.792721   32.015602
# temp_min_c        -15.364447   23.196047
# temp_range_c        1.331514   17.925816
# swe_mm              0.000000   77.876488
# swe_delta           0.000000   10.011885
# snow_cover_pct      0.000000   85.842361
# ...
